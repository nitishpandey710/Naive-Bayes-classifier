# %% [markdown]
# #-->1 Naive Bayes is a very Common Classifier used for Probablistic Multiclass classification.
# #-->2 Given the Feature vector,it uses the Bayes rule to predict the probability of each class.
# #-->3 There are three kind of Naive Bayes classifier each of them strong assumptions(hypothesis) about feature.
# #-->4 if you are dealing with real/continuous data the Gaussian Naive Bayes classifier assumes that features are generated
# #--from Gaussian process(that is they are normally distribured)

# %% [markdown]
# Using the Naive Bayes classifier to Predict the Class from Iris Dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.naive_bayes import GaussianNB

# %%
irisdf=pd.read_csv("Iris_external.csv")

# %%
irisdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# Sepal Length (in cm)    150 non-null float64
# Sepal Width in (cm)     150 non-null float64
# Petal length (in cm)    150 non-null float64
# Petal width (in cm)     150 non-null float64
# Class                   150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
irisdf.isnull().sum()
# Out:
# Sepal Length (in cm)    0
# Sepal Width in (cm)     0
# Petal length (in cm)    0
# Petal width (in cm)     0
# Class                   0
# dtype: int64

# %%
irisdf.head()
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  Petal length (in cm)  \
# 0                   5.1                  3.5                   1.4
# 1                   4.9                  3.0                   1.4
# 2                   4.7                  3.2                   1.3
# 3                   4.6                  3.1                   1.5
# 4                   5.0                  3.6                   1.4
#
#    Petal width (in cm)        Class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa
# 3                  0.2  Iris-setosa
# 4                  0.2  Iris-setosa

# %%
sns.pairplot(irisdf)

# %%
irisdf.corr()
# Out:
#                       Sepal Length (in cm)  Sepal Width in (cm)  \
# Sepal Length (in cm)              1.000000            -0.109369
# Sepal Width in (cm)              -0.109369             1.000000
# Petal length (in cm)              0.871754            -0.420516
# Petal width (in cm)               0.817954            -0.356544
#
#                       Petal length (in cm)  Petal width (in cm)
# Sepal Length (in cm)              0.871754             0.817954
# Sepal Width in (cm)              -0.420516            -0.356544
# Petal length (in cm)              1.000000             0.962757
# Petal width (in cm)               0.962757             1.000000

# %%
X=irisdf.drop('Class',axis=1)
y=irisdf['Class']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=1)

# %%
model=GaussianNB()
model.fit(X_train,y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
predicted=model.predict(X_test)
expected=y_test

# %%
model.score(X_train,y_train)
# Out:
# 0.9523809523809523

# %%
model.score(X_test,y_test)
# Out:
# 0.9333333333333333

# %%
from sklearn.metrics import classification_report
from sklearn import metrics

print(metrics.confusion_matrix(expected,predicted))
# Out:
# [[14  0  0]
#  [ 0 16  2]
#  [ 0  1 12]]

# %%
print(metrics.classification_report(expected,predicted))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        14
# Iris-versicolor       0.94      0.89      0.91        18
#  Iris-virginica       0.86      0.92      0.89        13
#
#        accuracy                           0.93        45
#       macro avg       0.93      0.94      0.93        45
#    weighted avg       0.94      0.93      0.93        45

# %%
#Accuracy is Better as data is less
